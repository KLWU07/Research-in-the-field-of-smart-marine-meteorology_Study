# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# 12个风电场的经纬度
coordinates = [
    (37.3823, 116.7217),  # 示例坐标
    (37.926389, 118.956667),
    (35.624167, 115.597222),
    (36.07496306, 118.8715818),
    (36.980285, 116.107164),
    (37.528, 121.014),
    (36.8988888888889, 121.080277777778),
    (37.775278, 120.698611),
    (36.99608932, 116.54250835),
    (37.55, 118.9),
    (36.173611, 119.716667),
    (35.3723, 115.48)
]

# 创建地图
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.PlateCarree()})
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAND, edgecolor='black')

# 标注风电场位置
for lat, lon in coordinates:
    ax.plot(lon, lat, 'ro', markersize=5, transform=ccrs.PlateCarree())
    ax.text(lon, lat, 'WF', transform=ccrs.PlateCarree())

# 显示地图
plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# 12个风电场的经纬度和名称
coordinates = [
    (37.3823, 116.7217, "WF1"),  # 示例坐标和名称
    (37.926389, 118.956667, "WF2"),
    (35.624167, 115.597222, "WF3"),
    (36.07496306, 118.8715818, "WF7"),
    (36.980285, 116.107164, "WF10"),
    (37.528, 121.014, "WF15"),
    (36.8988888888889, 121.080277777778, "WF16"),
    (37.775278, 120.698611, "WF17"),
    (36.99608932, 116.54250835, "WF19"),
    (37.55, 118.9, "WF20"),
    (36.173611, 119.716667, "WF21"),
    (35.3723, 115.48, "WF22")
]

# 创建地图
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.PlateCarree()})
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAND, edgecolor='black')

# 标注风电场位置和名称
for lat, lon, name in coordinates:
    ax.plot(lon, lat, 'ro', markersize=5, transform=ccrs.PlateCarree())  # 绘制点
    ax.text(lon, lat, name, transform=ccrs.PlateCarree(), fontsize=9, ha='right')  # 添加名称

# 显示地图
plt.title("Wind Farm Locations")
plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# 12个风电场的经纬度
coordinates = [
    (37.3823, 116.7217),  # 示例坐标
    (37.926389, 118.956667),
    (35.624167, 115.597222),
    (36.07496306, 118.8715818),
    (36.980285, 116.107164),
    (37.528, 121.014),
    (36.8988888888889, 121.080277777778),
    (37.775278, 120.698611),
    (36.99608932, 116.54250835),
    (37.55, 118.9),
    (36.173611, 119.716667),
    (35.3723, 115.48)
   
]

# 创建地图
fig, ax = plt.subplots(figsize=(10, 8), subplot_kw={'projection': ccrs.PlateCarree()})
ax.set_extent([114, 122, 35, 39], crs=ccrs.PlateCarree())  # 设置地图范围

# 添加地图特征
ax.add_feature(cfeature.COASTLINE, linewidth=1)
ax.add_feature(cfeature.BORDERS, linestyle=':', linewidth=1)
ax.add_feature(cfeature.LAND, edgecolor='black', facecolor='lightgray')

# 标注风电场位置
for lat, lon in coordinates:
    ax.plot(lon, lat, 'ro', markersize=5, transform=ccrs.PlateCarree())  # 绘制点
    ax.text(lon, lat, 'WF', transform=ccrs.PlateCarree(), fontsize=8, ha='right')  # 添加文本标注

# 添加标题
plt.title("Wind Farm Locations", fontsize=14)

# 显示地图
plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# 12个风电场的经纬度
coordinates = [
    (37.3823, 116.7217, "WF1"),  # 示例坐标和名称
    (37.926389, 118.956667, "WF2"),
    (35.624167, 115.597222, "WF3"),
    (36.07496306, 118.8715818, "WF7"),
    (36.980285, 116.107164, "WF10"),
    (37.528, 121.014, "WF15"),
    (36.8988888888889, 121.080277777778, "WF16"),
    (37.775278, 120.698611, "WF17"),
    (36.99608932, 116.54250835, "WF19"),
    (37.55, 118.9, "WF20"),
    (36.173611, 119.716667, "WF21"),
    (35.3723, 115.48, "WF22")
   
]

# 创建地图
fig, ax = plt.subplots(figsize=(10, 8), subplot_kw={'projection': ccrs.PlateCarree()})
ax.set_extent([114, 122, 35, 39], crs=ccrs.PlateCarree())  # 设置地图范围

# 添加地图特征
ax.add_feature(cfeature.COASTLINE, linewidth=1)
ax.add_feature(cfeature.BORDERS, linestyle=':', linewidth=1)
ax.add_feature(cfeature.LAND, edgecolor='black', facecolor='lightgray')

# 标注风电场位置和名称
for lat, lon, name in coordinates:
    ax.plot(lon, lat, 'ro', markersize=5, transform=ccrs.PlateCarree())  # 绘制点
    ax.text(lon, lat, name, transform=ccrs.PlateCarree(), fontsize=9, ha='right')  # 添加名称

# 添加标题
plt.title("Wind Farm Locations", fontsize=14)

# 显示地图
plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# 12个风电场的经纬度
coordinates = [
    (37.3823, 116.7217, "WF1"),  # 示例坐标和名称
    (37.926389, 118.956667, "WF2"),
    (35.624167, 115.597222, "WF3"),
    (36.07496306, 118.8715818, "WF7"),
    (36.980285, 116.107164, "WF10"),
    (37.528, 121.014, "WF15"),
    (36.8988888888889, 121.080277777778, "WF16"),
    (37.775278, 120.698611, "WF17"),
    (36.99608932, 116.54250835, "WF19"),
    (37.55, 118.9, "WF20"),
    (36.173611, 119.716667, "WF21"),
    (35.3723, 115.48, "WF22")
   
]

# 创建地图
fig, ax = plt.subplots(figsize=(10, 8), subplot_kw={'projection': ccrs.PlateCarree()})
ax.set_extent([114, 122, 35, 39], crs=ccrs.PlateCarree())  # 设置地图范围

# 添加地图特征
ax.add_feature(cfeature.COASTLINE, linewidth=1)
ax.add_feature(cfeature.BORDERS, linestyle=':', linewidth=1)
ax.add_feature(cfeature.LAND, edgecolor='black', facecolor='lightgray')

# 标注风电场位置和名称
for lat, lon, name in coordinates:
    ax.plot(lon, lat, 'ro', markersize=5, transform=ccrs.PlateCarree())  # 绘制点
    ax.text(lon, lat, name, transform=ccrs.PlateCarree(), fontsize=9, ha='right')  # 添加名称

# 添加经纬度网格线
gl = ax.gridlines(draw_labels=True, linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl.top_labels = False  # 关闭顶部标签
gl.right_labels = False  # 关闭右侧标签
gl.xlabel_style = {'size': 10, 'color': 'black'}  # 设置经度标签样式
gl.ylabel_style = {'size': 10, 'color': 'black'}  # 设置纬度标签样式

# 添加标题
plt.title("Wind Farm Locations", fontsize=14)

# 显示地图
plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# 12个风电场的经纬度
coordinates = [
    (37.3823, 116.7217, "WF1"),  # 示例坐标和名称
    (37.926389, 118.956667, "WF2"),
    (35.624167, 115.597222, "WF3"),
    (36.07496306, 118.8715818, "WF7"),
    (36.980285, 116.107164, "WF10"),
    (37.528, 121.014, "WF15"),
    (36.8988888888889, 121.080277777778, "WF16"),
    (37.775278, 120.698611, "WF17"),
    (36.99608932, 116.54250835, "WF19"),
    (37.55, 118.9, "WF20"),
    (36.173611, 119.716667, "WF21"),
    (35.3723, 115.48, "WF22")
]

# 创建地图
fig, ax = plt.subplots(figsize=(10, 8), subplot_kw={'projection': ccrs.PlateCarree()})
ax.set_extent([114, 122, 35, 39], crs=ccrs.PlateCarree())  # 设置地图范围

# 添加地图特征
ax.add_feature(cfeature.COASTLINE, linewidth=1)
ax.add_feature(cfeature.BORDERS, linestyle=':', linewidth=1)
ax.add_feature(cfeature.LAND, edgecolor='black', facecolor='lightgray')

# 标注风电场位置和名称
for lat, lon, name in coordinates:
    ax.plot(lon, lat, 'ro', markersize=5, transform=ccrs.PlateCarree())  # 绘制点
    ax.text(lon, lat, name, transform=ccrs.PlateCarree(), fontsize=9, ha='right')  # 添加名称

# 添加横纵坐标刻度标签（不显示网格线）
gl = ax.gridlines(draw_labels=True, linewidth=0, color='none')  # 设置 linewidth=0 和 color='none' 隐藏网格线
gl.top_labels = False  # 关闭顶部标签
gl.right_labels = False  # 关闭右侧标签
gl.xlabel_style = {'size': 10, 'color': 'black'}  # 设置经度标签样式
gl.ylabel_style = {'size': 10, 'color': 'black'}  # 设置纬度标签样式

# 添加标题
plt.title("Wind Farm Locations", fontsize=14)

# 显示地图
plt.show()

# %%
# 保存地图到电脑
output_path = "wind_farm_map.png"  # 文件保存路径
plt.savefig(output_path, dpi=300, bbox_inches='tight')  # 保存为 PNG 文件，dpi 设置分辨率
print(f"地图已保存到: {output_path}")
# Out:
# 地图已保存到: wind_farm_map.png

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# 12个风电场的经纬度
coordinates = [
    (37.3823, 116.7217, "WF1"),  # 示例坐标和名称
    (37.926389, 118.956667, "WF2"),
    (35.624167, 115.597222, "WF3"),
    (36.07496306, 118.8715818, "WF7"),
    (36.980285, 116.107164, "WF10"),
    (37.528, 121.014, "WF15"),
    (36.8988888888889, 121.080277777778, "WF16"),
    (37.775278, 120.698611, "WF17"),
    (36.99608932, 116.54250835, "WF19"),
    (37.55, 118.9, "WF20"),
    (36.173611, 119.716667, "WF21"),
    (35.3723, 115.48, "WF22")
]

# 创建地图
fig, ax = plt.subplots(figsize=(10, 8), subplot_kw={'projection': ccrs.PlateCarree()})
ax.set_extent([114, 122, 35, 39], crs=ccrs.PlateCarree())  # 设置地图范围

# 添加地图特征
ax.add_feature(cfeature.COASTLINE, linewidth=1)
ax.add_feature(cfeature.BORDERS, linestyle=':', linewidth=1)
ax.add_feature(cfeature.LAND, edgecolor='black', facecolor='lightgray')

# 标注风电场位置和名称
for lat, lon, name in coordinates:
    ax.plot(lon, lat, 'ro', markersize=5, transform=ccrs.PlateCarree())  # 绘制点
    ax.text(lon, lat, name, transform=ccrs.PlateCarree(), fontsize=9, ha='right')  # 添加名称

# 添加横纵坐标刻度标签（不显示网格线）
gl = ax.gridlines(draw_labels=True, linewidth=0, color='none')  # 设置 linewidth=0 和 color='none' 隐藏网格线
gl.top_labels = False  # 关闭顶部标签
gl.right_labels = False  # 关闭右侧标签
gl.xlabel_style = {'size': 10, 'color': 'black'}  # 设置经度标签样式
gl.ylabel_style = {'size': 10, 'color': 'black'}  # 设置纬度标签样式

# 添加标题
plt.title("Wind Farm Locations", fontsize=14)

# 保存地图到电脑
output_path = "wind_farm_map.png"  # 文件保存路径
plt.savefig(output_path, dpi=300, bbox_inches='tight')  # 保存为 PNG 文件，dpi 设置分辨率
print(f"地图已保存到: {output_path}")

# 显示地图
plt.show()
# Out:
# 地图已保存到: wind_farm_map.png
